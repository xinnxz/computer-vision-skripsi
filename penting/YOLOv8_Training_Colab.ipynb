# %% [markdown]
# <a href="https://colab.research.google.com"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 🚀 Training YOLOv8 - Deteksi Barang Gudang (38 Kelas)
# **Skripsi: Sistem Pendeteksian Barang Gudang Berbasis Computer Vision**
#
# ---
# ## 📋 Daftar Isi
# 1. [Setup GPU & Install Library](#setup)
# 2. [Mount Google Drive & Upload Dataset](#dataset)
# 3. [Persiapan Dataset & Validasi](#validasi)
# 4. [Training Model YOLOv8](#training)
# 5. [Evaluasi & Visualisasi Hasil](#evaluasi)
# 6. [Download Model (best.pt)](#download)
#
# ---
# ### ⚙️ Konfigurasi Dataset
# | Parameter | Nilai |
# |-----------|-------|
# | Total gambar train | 710 |
# | Total gambar val | 195 |
# | Total class | **38 class** |
# | Format label | Bounding Box + Polygon (mixed, didukung YOLOv8) |
# | Model dasar | YOLOv8n (Nano) - cepat & ringan |

# %% [markdown]
# ---
# ## Sel 1: Cek GPU & Install Library
# > **Penting!** Pastikan Colab sudah menggunakan GPU. Klik menu **Runtime → Change runtime type → T4 GPU** sebelum menjalankan notebook ini.

# %%
# ============================================================
# CEK GPU
# ============================================================
import subprocess
result = subprocess.run(['nvidia-smi'], capture_output=True, text=True)
if result.returncode == 0:
    print("✅ GPU TERDETEKSI! Training akan berjalan cepat.")
    print(result.stdout[:500])
else:
    print("❌ GPU TIDAK TERDETEKSI!")
    print("   → Klik Runtime → Change runtime type → Hardware accelerator: T4 GPU")
    print("   → Lalu restart runtime dan jalankan ulang dari sel ini.")

# ============================================================
# INSTALL ULTRALYTICS (YOLOv8)
# ============================================================
print("\n📦 Menginstall Ultralytics...")
# !pip install ultralytics --quiet

import ultralytics
ultralytics.checks()
print("\n✅ Ultralytics siap digunakan!")
# Out:
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.7/112.6 GB disk)
#
# ✅ Ultralytics siap digunakan!

# %% [markdown]
# ---
# ## Sel 2: Mount Google Drive
# > Dataset akan diupload ke Google Drive terlebih dahulu agar tidak perlu upload ulang setiap kali session Colab habis.
# >
# > **Langkah sebelum menjalankan sel ini:**
# > 1. Zip folder `dataset_final` dari laptop Mas Luthfi (klik kanan → Send to → Compressed folder)
# > 2. Upload file `dataset_final.zip` ke **Google Drive** (bebas di folder mana saja)
# > 3. Salin PATH folder tempat file zip tersimpan (misal: `MyDrive/skripsi/dataset_final.zip`)
# > 4. Jalankan sel ini, lalu izinkan akses Google Drive

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')
print("✅ Google Drive berhasil terhubung!")

# ============================================================
# KONFIGURASI PATH - SESUAIKAN DENGAN LOKASI FILE ZIP ANDA
# ============================================================

# Ganti path ini sesuai lokasi dataset_final.zip di Google Drive Mas Luthfi
GDRIVE_ZIP_PATH = '/content/drive/MyDrive/DICODING/dataset_final (1).zip'   # <-- GANTI INI

# Path tujuan ekstrak di Colab (jangan diubah)
COLAB_DATASET_DIR = '/content/dataset_final'
YAML_PATH = f'{COLAB_DATASET_DIR}/data.yaml'

# Nama run training
RUN_NAME = 'model_gudang_v2'

print(f"\n📂 Path zip    : {GDRIVE_ZIP_PATH}")
print(f"📂 Path dataset: {COLAB_DATASET_DIR}")

# Cek apakah file zip ada
if os.path.exists(GDRIVE_ZIP_PATH):
    print(f"✅ File zip ditemukan!")
else:
    print(f"❌ File zip TIDAK ditemukan di: {GDRIVE_ZIP_PATH}")
    print("   → Pastikan path GDRIVE_ZIP_PATH di atas sudah benar.")
# Out:
# Mounted at /content/drive
# ✅ Google Drive berhasil terhubung!
#
# 📂 Path zip    : /content/drive/MyDrive/DICODING/dataset_final (1).zip
# 📂 Path dataset: /content/dataset_final
# ✅ File zip ditemukan!

# %% [markdown]
# ---
# ## Sel 3: Ekstrak Dataset

# %%
import zipfile
import shutil
import time

# Hapus folder lama jika ada (agar ekstraksi bersih)
if os.path.exists(COLAB_DATASET_DIR):
    print(f"🗑️  Menghapus folder lama: {COLAB_DATASET_DIR}")
    shutil.rmtree(COLAB_DATASET_DIR)

print(f"📦 Mengekstrak dataset dari: {GDRIVE_ZIP_PATH}")
print("    (Proses ini mungkin memakan beberapa menit untuk dataset besar...)")

start = time.time()
with zipfile.ZipFile(GDRIVE_ZIP_PATH, 'r') as zip_ref:
    for member in zip_ref.infolist():
        member.filename = member.filename.replace('\\', '/')
        zip_ref.extract(member, '/content/')
elapsed = time.time() - start

print(f"\n✅ Dataset berhasil diekstrak dalam {elapsed:.1f} detik!")

# Verifikasi struktur folder
print("\n📂 Struktur folder dataset:")
for split in ['train', 'val']:
    img_dir = os.path.join(COLAB_DATASET_DIR, split, 'images')
    lbl_dir = os.path.join(COLAB_DATASET_DIR, split, 'labels')
    if os.path.exists(img_dir):
        n_img = len(os.listdir(img_dir))
        n_lbl = len(os.listdir(lbl_dir)) if os.path.exists(lbl_dir) else 0
        print(f"  {split}/images : {n_img} gambar")
        print(f"  {split}/labels : {n_lbl} file label")
    else:
        print(f"  ❌ Folder {split} TIDAK ditemukan!")
# Out:
# 📦 Mengekstrak dataset dari: /content/drive/MyDrive/DICODING/dataset_final (1).zip
#     (Proses ini mungkin memakan beberapa menit untuk dataset besar...)
#
# ✅ Dataset berhasil diekstrak dalam 23.3 detik!
#
# 📂 Struktur folder dataset:
#   train/images : 710 gambar
#   train/labels : 710 file label
#   val/images : 98 gambar
#   val/labels : 98 file label

# %% [markdown]
# ---
# ## Sel 4: Update data.yaml untuk Google Colab
# > File `data.yaml` dari laptop Mas Luthfi menggunakan path lokal (`path: .`). Di Colab, path-nya harus diubah menjadi path absolut Colab agar YOLOv8 bisa menemukan gambar-gambarnya.

# %%
import yaml

# Baca data.yaml yang ada
with open(YAML_PATH, 'r') as f:
    data = yaml.safe_load(f)

# Update path ke path absolut Colab
data['path']  = COLAB_DATASET_DIR
data['train'] = 'train/images'
data['val']   = 'val/images'

# Simpan kembali
with open(YAML_PATH, 'w') as f:
    yaml.dump(data, f, allow_unicode=True, sort_keys=False, default_flow_style=False)

print("✅ data.yaml berhasil diupdate!")
print(f"   path  : {data['path']}")
print(f"   train : {data['train']}")
print(f"   val   : {data['val']}")
print(f"   nc    : {data.get('nc', 'tidak ada')} class")
print(f"\n📋 Daftar {data.get('nc')} Class:")
names = data.get('names', {})
if isinstance(names, list):
    names = {i: v for i, v in enumerate(names)}
for idx in sorted(names.keys()):
    print(f"  [{idx:>2}] {names[idx]}")
# Out:
# ✅ data.yaml berhasil diupdate!
#    path  : /content/dataset_final
#    train : train/images
#    val   : val/images
#    nc    : 38 class
#
# 📋 Daftar 38 Class:
#   [ 0] Bawang Merah
#   [ 1] Bawang Putih
#   [ 2] Bihun
#   [ 3] Bumbu Racik
#   [ 4] Delta Foods Tongkol
#   [ 5] Garam
#   [ 6] Gula Merah
#   [ 7] Gula Putih
#   [ 8] Ikan Teri Dus
#   [ 9] Jahe
#   [10] Kecap Manis
#   [11] Kencur
#   [12] Kerupuk Makaroni
#   [13] Kerupuk Rambak
#   [14] Kunyit
#   [15] Lada Putih
#   [16] Lengkuas
#   [17] Masako
#   [18] Masako Dus
#   [19] Mie Burung Dara
#   [20] Minyak Fortune Dus
#   [21] Royco
#   [22] Salam
#   [23] Santan Rose Brand
#   [24] Saori Saos Tiram
#   [25] Sasa
#   [26] Sasa Bumbu Kaldu Ayam
#   [27] Sasa Santan Kelapa
#   [28] Saus Cabe
#   [29] Sereh
#   [30] Sinti Dus
#   [31] Susu RealGood Dus
#   [32] Telur
#   [33] Telur Asin
#   [34] Bubuk Ayam
#   [35] Bumbu Masak Daisys
#   [36] Kerupuk Jengkol
#   [37] Santan Kelapa Kara

# %% [markdown]
# ---
# ## Sel 5: 🏋️ TRAINING MODEL YOLOv8
# > Ini adalah sel utama yang menjalankan proses pelatihan (training).
# >
# > **Penjelasan Parameter Penting:**
# > | Parameter | Nilai | Penjelasan |
# > |-----------|-------|------------|
# > | `model` | `yolov8n.pt` | Model dasar (nano = paling ringan, cocok untuk Colab gratis) |
# > | `epochs` | `100` | Jumlah putaran belajar. Lebih tinggi = lebih pintar (tapi lama) |
# > | `imgsz` | `640` | Ukuran gambar saat training (standar YOLOv8) |
# > | `batch` | `16` | Jumlah gambar per batch. Turunkan ke 8 jika Colab RAM habis |
# > | `patience` | `30` | Berhenti otomatis jika tidak ada kemajuan selama 30 epoch |
# > | `optimizer` | `AdamW` | Optimizer terbaik untuk dataset kecil-menengah |
# > | `lr0` | `0.001` | Learning rate awal |
# > | `augment` | `True` | Data augmentation otomatis (biar model lebih tahan banting) |

# %%
from ultralytics import YOLO
import torch

print(f"🖥️  Device: {'GPU - ' + torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU (lambat!)'}")
print(f"📂 Dataset YAML: {YAML_PATH}")
print(f"🏷️  Nama Run    : {RUN_NAME}")
print("\n" + "="*60)
print("  MEMULAI TRAINING... Jangan tutup tab ini!")
print("  Estimasi waktu: 20-40 menit di GPU T4 Colab")
print("="*60 + "\n")

# Load model dasar YOLOv8 nano (pre-trained pada ImageNet)
model = YOLO('yolov8m.pt')

# ============================================================
# JALANKAN TRAINING
# ============================================================
results = model.train(
    data      = YAML_PATH,      # Path ke data.yaml
    epochs    = 200,            # Jumlah epoch
    imgsz     = 800,            # Ukuran gambar
    batch     = 16,             # Batch size (turunkan ke 8 jika OOM)
    patience  = 30,             # Early stopping
    optimizer = 'AdamW',        # Optimizer
    lr0       = 0.001,          # Learning rate awal
    lrf       = 0.01,           # Learning rate akhir (fraction)
    augment   = True,           # Augmentasi otomatis
    mosaic    = 1.0,            # Mosaic augmentation (bagus untuk multi-class)
    mixup     = 0.1,            # Mixup augmentation
    degrees   = 10.0,           # Rotasi gambar (max 10 derajat)
    fliplr    = 0.5,            # Flip horizontal 50%
    hsv_h     = 0.015,          # Variasi Hue
    hsv_s     = 0.7,            # Variasi Saturation
    hsv_v     = 0.4,            # Variasi Value/Brightness
    project   = 'runs/detect',  # Folder output
    name      = RUN_NAME,       # Nama subfolder output
    save      = True,           # Simpan checkpoint
    save_period = 10,           # Simpan checkpoint tiap 10 epoch
    plots     = True,           # Generate grafik training otomatis
    verbose   = True,           # Tampilkan log detail
)

print("\n" + "="*60)
print("  ✅ TRAINING SELESAI!")
print(f"  Model terbaik tersimpan di: runs/detect/{RUN_NAME}/weights/best.pt")
print("="*60)
# Out:
# 🖥️  Device: GPU - Tesla T4
# 📂 Dataset YAML: /content/dataset_final/data.yaml
# 🏷️  Nama Run    : model_gudang_v2
#
# ============================================================
#   MEMULAI TRAINING... Jangan tutup tab ini!
#   Estimasi waktu: 20-40 menit di GPU T4 Colab
# ============================================================
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 203.4MB/s 0.0s
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset_final/data.yaml, degrees=10.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=model_gudang_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/detect/model_gudang_v2, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 101.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=38
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    758722  ultralytics.nn.modules.head.Detect           [38, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,018,258 parameters, 3,018,242 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 283.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3923.1±1094.3 MB/s, size: 1022.8 KB)
# train: Scanning /content/dataset_final/train/labels... 710 images, 102 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 710/710 210.6it/s 3.4s
# train: /content/dataset_final/train/images/20260704_105439.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260704_105444.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260715_102226.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260715_102819.jpg: corrupt JPEG restored and saved
# train: New cache created: /content/dataset_final/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 3188, len(boxes) = 3651. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1215.6±1127.5 MB/s, size: 1065.6 KB)
# val: Scanning /content/dataset_final/val/labels... 98 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 98/98 609.3it/s 0.2s
# val: New cache created: /content/dataset_final/val/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 606. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/runs/detect/model_gudang_v2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/model_gudang_v2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.23G      1.418       3.85      1.402         94        640: 100% ━━━━━━━━━━━━ 45/45 1.5s/it 1:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3s/it 5.1s
#                    all         98        606    0.00541      0.173     0.0224     0.0106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.36G      1.359       2.83      1.348         59        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.9it/s 1.4s
#                    all         98        606      0.535     0.0946      0.126     0.0628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.36G      1.347      2.284      1.322         93        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s
#                    all         98        606      0.367      0.299      0.232      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.36G      1.317      2.181      1.342         89        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606       0.45      0.335      0.322      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.36G      1.306      1.892      1.305         84        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s
#                    all         98        606        0.6      0.367      0.475        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.36G      1.242      1.798      1.291         31        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s
#                    all         98        606      0.471      0.584      0.509      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.36G      1.233      1.676      1.273         30        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s
#                    all         98        606      0.588      0.503      0.554      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.36G      1.204       1.55      1.261         79        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.635      0.545      0.574      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.36G      1.219      1.476      1.251         63        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.676      0.515      0.592      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.36G      1.207      1.386      1.242         78        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.6it/s 0.9s
#                    all         98        606      0.555      0.621      0.662       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.36G      1.221      1.369      1.236         62        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.612      0.671      0.675      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.36G      1.134      1.344      1.221         30        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 49.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.6s
#                    all         98        606      0.757      0.559      0.687      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.36G      1.147      1.322      1.218         79        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.9it/s 1.0s
#                    all         98        606      0.646      0.691      0.702      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.36G      1.146      1.274       1.21         66        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606       0.67      0.601       0.71      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.36G      1.144      1.241        1.2         32        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 1:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.691       0.66      0.724      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.36G      1.119      1.255      1.204         92        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.664      0.644      0.739       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.49G      1.121      1.215      1.185         85        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all         98        606      0.736      0.622      0.733      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.49G      1.083      1.146       1.19         39        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 49.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.662       0.67      0.754      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.49G      1.113      1.171      1.201         33        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s
#                    all         98        606      0.722      0.669      0.771      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.49G      1.058      1.104      1.168         90        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.3s
#                    all         98        606      0.663      0.749      0.737      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.49G      1.062      1.084      1.168         88        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s
#                    all         98        606      0.741       0.65       0.74      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.49G      1.054      1.018       1.14        107        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.3s
#                    all         98        606      0.772      0.665      0.749      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.49G      1.049      1.032       1.15         91        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.785      0.688      0.776      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.49G      1.033     0.9882      1.145         39        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606      0.697      0.711      0.752      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.49G      1.016     0.9761      1.131         31        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.636      0.762      0.793      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.49G      1.027      1.016      1.147         49        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.699      0.762      0.817      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.49G      1.038      1.018       1.16         65        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.7it/s 1.5s
#                    all         98        606      0.827      0.686      0.772      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.49G      1.017     0.9648      1.144         51        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.1it/s 1.9s
#                    all         98        606      0.715      0.719      0.773      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.49G      1.028     0.9702      1.146         73        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.5s
#                    all         98        606       0.72      0.719       0.78      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.49G      1.002     0.9631      1.134         78        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.628      0.829      0.799      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.49G     0.9936     0.9575      1.132         93        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606      0.708      0.762      0.798      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.49G      1.008     0.9247      1.125         75        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 51.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606       0.77      0.766      0.812      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.49G     0.9777     0.8954       1.11         42        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.7s
#                    all         98        606      0.824        0.7      0.798      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.49G     0.9937     0.8951      1.124         53        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s
#                    all         98        606      0.751      0.723      0.779      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.49G     0.9631     0.8929      1.111         65        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 51.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.701       0.75      0.803      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.49G      0.964     0.8774      1.112         57        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.3it/s 0.9s
#                    all         98        606       0.77      0.726      0.786      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.49G     0.9686      0.898      1.112        103        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 1:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.764      0.755      0.806       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.49G     0.9715     0.8708      1.105         46        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.5s
#                    all         98        606      0.808      0.701      0.794      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.49G      0.961     0.8706      1.109         58        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 51.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606       0.75      0.766      0.842      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.49G     0.9516     0.8703      1.112         38        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all         98        606      0.788      0.753      0.848      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.49G     0.9195     0.8538      1.101         37        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.781      0.763      0.816      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.49G     0.9443     0.8507      1.106         85        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.812      0.744      0.821      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.49G     0.9369     0.8414      1.104         45        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 1:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all         98        606      0.719        0.8      0.837      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.49G     0.9557     0.8705      1.117         49        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.788      0.752      0.835       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.49G      0.922     0.8205      1.098        115        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 49.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s
#                    all         98        606      0.692      0.815      0.812      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.49G     0.9128     0.7994      1.081         65        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 51.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.706       0.81      0.829       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.49G     0.9444     0.8224      1.098         26        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4it/s 1.7s
#                    all         98        606       0.83      0.719      0.814      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.49G     0.9139     0.8157      1.099        116        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 49.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.802      0.757      0.807       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.49G     0.8993     0.7835       1.08         57        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.694      0.831      0.834      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.49G     0.8856      0.768      1.083        127        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.777      0.748      0.808      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.49G     0.9264      0.807      1.104         14        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.1it/s 1.9s
#                    all         98        606      0.797      0.769      0.825       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.49G     0.9053     0.7942      1.082         21        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.1s
#                    all         98        606      0.764      0.801      0.841      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.49G     0.9211     0.7728      1.074        102        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606       0.66      0.815      0.821      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.49G     0.8743     0.7669      1.072        123        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606       0.74      0.775      0.828      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.49G     0.8661     0.7482      1.057         65        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.669      0.807      0.809      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.49G     0.8422     0.7184      1.054         67        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s
#                    all         98        606      0.655      0.864      0.818      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.49G     0.8768     0.7384      1.074         28        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 56.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.722      0.821      0.858      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.49G     0.8773     0.7616      1.078         38        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.737      0.824      0.853      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.49G     0.8783      0.759      1.062         58        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all         98        606      0.666      0.876      0.817      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.49G     0.8711     0.7375      1.057         76        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 1:00
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s
#                    all         98        606      0.702      0.849       0.84      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.49G     0.8645     0.7444      1.069         58        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.0s
#                    all         98        606      0.723      0.823      0.834      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.49G     0.8568     0.7197      1.065         35        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s
#                    all         98        606      0.726      0.813       0.83      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.49G     0.9041      0.745      1.066        108        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4it/s 1.7s
#                    all         98        606      0.734      0.825      0.821      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.49G     0.8696     0.7232      1.059         69        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 58.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all         98        606      0.731      0.779       0.81      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.49G     0.8528     0.7291      1.064         67        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606       0.77      0.787      0.832      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.49G     0.8358      0.711      1.048         55        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s
#                    all         98        606      0.735      0.829      0.838      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.49G     0.8484     0.7324      1.066         51        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606      0.733      0.854      0.846      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.49G     0.8206     0.6955      1.035         65        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606       0.71      0.827      0.828      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.49G     0.8316     0.7092      1.055         91        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all         98        606      0.803      0.764      0.837      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.49G     0.8278     0.7043      1.047         19        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 56.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all         98        606      0.725      0.835      0.833      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.49G     0.8728      0.705      1.062         98        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.757      0.817      0.842      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.49G     0.8137     0.6646      1.036         42        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.788      0.802      0.843      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.49G     0.8226     0.6856      1.044         53        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 51.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.685      0.886       0.85      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.49G     0.8018     0.6719      1.041         80        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 56.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.4it/s 0.9s
#                    all         98        606      0.758      0.829       0.85      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.49G     0.8171     0.6785      1.047         67        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.7s
#                    all         98        606      0.761      0.819       0.84      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.49G      0.814     0.6999      1.049         31        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.7it/s 1.5s
#                    all         98        606      0.673      0.884       0.84      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.49G     0.8126     0.6648      1.036        112        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.782      0.829      0.853       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.49G     0.7895     0.6756      1.036         57        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 53.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.791      0.806      0.864      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.49G      0.818     0.6598      1.042         46        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.695       0.86      0.858      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.49G     0.8223     0.6554      1.031         51        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 59.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.716      0.841      0.853      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.49G     0.8222     0.6665      1.047         19        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.752      0.824      0.868      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.49G     0.7926     0.6494      1.026         91        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.6it/s 1.5s
#                    all         98        606      0.807      0.781      0.853      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.49G     0.7768     0.6229      1.008         23        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all         98        606      0.776      0.795      0.848      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.49G     0.7886     0.6582       1.03         90        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.775      0.783      0.841      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.49G     0.8058     0.6605      1.029        103        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2it/s 1.8s
#                    all         98        606      0.739      0.842      0.858      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.49G      0.784     0.6445      1.014         59        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s
#                    all         98        606      0.764      0.816      0.857      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.49G     0.7675     0.6391      1.023         32        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4it/s 1.7s
#                    all         98        606      0.746      0.862      0.856      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.49G     0.7785     0.6432      1.025         88        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3it/s 1.8s
#                    all         98        606      0.761      0.836      0.853      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.49G     0.7757     0.6486      1.032        114        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.757      0.827      0.854      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.49G     0.7943     0.6606      1.026         90        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.1s
#                    all         98        606      0.764      0.818      0.855      0.736
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.49G      0.695     0.6074     0.9954          6        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 1:01
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s
#                    all         98        606      0.784      0.794      0.849      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.49G      0.677     0.5848     0.9921          6        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.9it/s 1.4s
#                    all         98        606      0.764      0.801      0.847      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.49G     0.6531     0.5442     0.9539         58        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.8it/s 1.1s
#                    all         98        606      0.743      0.835      0.838      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.49G     0.6543     0.5302     0.9578         41        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.798      0.789      0.843      0.725
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.49G     0.6433     0.5444     0.9612         20        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 55.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s
#                    all         98        606      0.782        0.8      0.843      0.722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.49G     0.6405     0.5218     0.9516         29        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s
#                    all         98        606      0.791      0.802       0.85      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.49G     0.6292     0.5312     0.9633          6        640: 100% ━━━━━━━━━━━━ 45/45 1.0s/it 46.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.757       0.83       0.85      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.49G     0.6328      0.526     0.9637          6        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.769      0.815      0.857       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.49G      0.629     0.5162     0.9543         51        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4it/s 1.7s
#                    all         98        606      0.798       0.79      0.859      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.49G     0.6193     0.5178     0.9582         17        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 49.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s
#                    all         98        606      0.791      0.791      0.858      0.747
#
# 100 epochs completed in 1.626 hours.
# Optimizer stripped from /content/runs/detect/runs/detect/model_gudang_v2/weights/last.pt, 6.2MB
# Optimizer stripped from /content/runs/detect/runs/detect/model_gudang_v2/weights/best.pt, 6.2MB
#
# Validating /content/runs/detect/runs/detect/model_gudang_v2/weights/best.pt...
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,013,058 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.7s/it 6.7s
#                    all         98        606      0.797      0.838      0.871      0.757
#           Bawang Merah         12         16      0.855          1      0.975      0.763
#           Bawang Putih          5          5      0.928        0.8      0.962      0.533
#                  Bihun         20        169       0.92      0.959      0.945      0.806
#            Bumbu Racik          7         14      0.854      0.839      0.923      0.785
#    Delta Foods Tongkol          1          1      0.815          1      0.995      0.995
#                  Garam         10         32      0.916       0.68      0.859      0.602
#             Gula Merah          1          1      0.814          1      0.995      0.995
#          Ikan Teri Dus          3          3      0.808          1      0.995      0.995
#                   Jahe          2          2      0.517      0.552      0.828      0.613
#            Kecap Manis         15         25      0.875        0.8      0.908      0.796
#                 Kencur          3          3       0.62      0.333      0.555      0.396
#       Kerupuk Makaroni          6         12      0.524      0.461      0.493      0.359
#         Kerupuk Rambak          5         12      0.972      0.833      0.898      0.757
#                 Kunyit          3          3      0.639      0.612       0.83      0.696
#             Lada Putih         12         16      0.991      0.812      0.864      0.734
#               Lengkuas          2          2      0.497      0.992      0.497      0.497
#                 Masako          1          1      0.811          1      0.995      0.995
#             Masako Dus          3          3      0.939          1      0.995       0.94
#        Mie Burung Dara         16        136      0.884      0.893       0.93      0.736
#     Minyak Fortune Dus          2          2      0.875          1      0.995      0.995
#                  Royco          3          3      0.913          1      0.995      0.995
#                  Salam          1          1      0.671          1      0.995      0.995
#      Santan Rose Brand         11         11      0.893          1      0.935      0.856
#       Saori Saos Tiram         10         14      0.936          1      0.995       0.84
#                   Sasa         14         30       0.87      0.867      0.877      0.665
#  Sasa Bumbu Kaldu Ayam         10         11      0.972      0.909      0.946      0.871
#     Sasa Santan Kelapa          3          3      0.913          1      0.995      0.995
#              Saus Cabe         10         10      0.906      0.963      0.977      0.838
#              Sinti Dus         11         24      0.943      0.875      0.923      0.774
#                  Telur          1          1          0          0     0.0452     0.0452
#             Telur Asin          1          1      0.821          1      0.995      0.895
#             Bubuk Ayam         14         20      0.591      0.507      0.671       0.45
#     Bumbu Masak Daisys          9         11      0.872      0.818       0.82      0.685
#     Santan Kelapa Kara          8          8      0.758          1      0.995      0.852
# Speed: 0.5ms preprocess, 48.6ms inference, 0.0ms loss, 4.8ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/model_gudang_v2
#
# ============================================================
#   ✅ TRAINING SELESAI!
#   Model terbaik tersimpan di: runs/detect/model_gudang_v2/weights/best.pt
# ============================================================

# %% [markdown]
# ---
# ## Sel 6: 📊 Evaluasi Model (Metrik Akurasi)
# > Setelah training selesai, jalankan sel ini untuk melihat nilai akurasi model (mAP50, Precision, Recall).
# >
# > **Penjelasan Metrik:**
# > - **Precision**: Dari semua deteksi model, berapa % yang benar?
# > - **Recall**: Dari semua objek yang ada, berapa % yang berhasil dideteksi?
# > - **mAP50**: Mean Average Precision pada IoU 50% — metrik utama YOLOv8. Semakin tinggi semakin bagus (target: > 0.70)
# > - **mAP50-95**: mAP yang lebih ketat, dihitung di berbagai threshold IoU.

# %%
from ultralytics import YOLO

# Load model terbaik hasil training
best_model_path = f'runs/detect/runs/detect/{RUN_NAME}/weights/best.pt'
model_best = YOLO(best_model_path)

# Jalankan validasi
print("🔍 Menjalankan evaluasi model pada data validasi...")
metrics = model_best.val(data=YAML_PATH, imgsz=640, batch=16, verbose=True)

print("\n" + "="*60)
print("  📊 HASIL EVALUASI MODEL")
print("="*60)
print(f"  Precision (P)  : {metrics.box.mp:.4f}  ({metrics.box.mp*100:.2f}%)")
print(f"  Recall    (R)  : {metrics.box.mr:.4f}  ({metrics.box.mr*100:.2f}%)")
print(f"  mAP@50         : {metrics.box.map50:.4f}  ({metrics.box.map50*100:.2f}%)")
print(f"  mAP@50-95      : {metrics.box.map:.4f}  ({metrics.box.map*100:.2f}%)")
print("="*60)

if metrics.box.map50 >= 0.70:
    print("  ✅ Akurasi BAGUS! Model siap digunakan.")
elif metrics.box.map50 >= 0.50:
    print("  ⚠️  Akurasi CUKUP. Pertimbangkan tambah epoch atau data.")
else:
    print("  ❌ Akurasi RENDAH. Perlu lebih banyak data atau epoch.")
# Out:
# 🔍 Menjalankan evaluasi model pada data validasi...
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,013,058 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3898.6±1959.5 MB/s, size: 818.6 KB)
# val: Scanning /content/dataset_final/val/labels.cache... 98 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 98/98 31.6Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 606. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s
#                    all         98        606      0.773       0.81      0.859      0.749
#           Bawang Merah         12         16       0.82          1       0.97      0.786
#           Bawang Putih          5          5      0.792        0.8      0.787      0.546
#                  Bihun         20        169      0.906      0.959      0.939      0.804
#            Bumbu Racik          7         14       0.76      0.857      0.928       0.78
#    Delta Foods Tongkol          1          1      0.768          1      0.995      0.995
#                  Garam         10         32      0.852      0.719       0.87      0.589
#             Gula Merah          1          1      0.768          1      0.995      0.895
#          Ikan Teri Dus          3          3      0.779          1      0.995      0.962
#                   Jahe          2          2      0.432        0.5      0.662      0.405
#            Kecap Manis         15         25      0.774       0.96      0.891      0.788
#                 Kencur          3          3      0.742      0.333      0.555      0.403
#       Kerupuk Makaroni          6         12      0.384      0.333      0.388       0.28
#         Kerupuk Rambak          5         12          1       0.71      0.903      0.712
#                 Kunyit          3          3      0.593      0.519       0.83      0.781
#             Lada Putih         12         16      0.988      0.812      0.871       0.74
#               Lengkuas          2          2      0.407      0.407      0.497       0.46
#                 Masako          1          1      0.771          1      0.995      0.895
#             Masako Dus          3          3          1      0.811      0.995       0.94
#        Mie Burung Dara         16        136      0.881      0.912      0.931      0.724
#     Minyak Fortune Dus          2          2      0.843          1      0.995      0.895
#                  Royco          3          3      0.883          1      0.995      0.995
#                  Salam          1          1      0.844          1      0.995      0.995
#      Santan Rose Brand         11         11      0.887          1      0.927      0.872
#       Saori Saos Tiram         10         14       0.93      0.949      0.986      0.864
#                   Sasa         14         30      0.888        0.9      0.922      0.712
#  Sasa Bumbu Kaldu Ayam         10         11      0.958      0.909      0.905       0.86
#     Sasa Santan Kelapa          3          3      0.888          1      0.995       0.94
#              Saus Cabe         10         10      0.766          1      0.978      0.876
#              Sinti Dus         11         24      0.962      0.833      0.905      0.804
#                  Telur          1          1          0          0      0.124      0.124
#             Telur Asin          1          1      0.778          1      0.995      0.995
#             Bubuk Ayam         14         20      0.635        0.5      0.694      0.487
#     Bumbu Masak Daisys          9         11      0.865      0.818      0.804      0.709
#     Santan Kelapa Kara          8          8      0.753          1      0.982      0.854
# Speed: 5.3ms preprocess, 5.8ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /content/runs/detect/val
#
# ============================================================
#   📊 HASIL EVALUASI MODEL
# ============================================================
#   Precision (P)  : 0.7734  (77.34%)
#   Recall    (R)  : 0.8101  (81.01%)
#   mAP@50         : 0.8588  (85.88%)
#   mAP@50-95      : 0.7490  (74.90%)
# ============================================================
#   ✅ Akurasi BAGUS! Model siap digunakan.

# %% [markdown]
# ---
# ## Sel 7: 🖼️ Visualisasi Grafik Training

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

result_dir = f'runs/detect/{RUN_NAME}'

# Daftar gambar grafik yang di-generate otomatis oleh YOLOv8
plot_files = {
    'results.png'       : 'Grafik Training (Loss & Metrik per Epoch)',
    'confusion_matrix.png': 'Confusion Matrix',
    'val_batch0_pred.jpg' : 'Contoh Prediksi Batch Validasi',
    'PR_curve.png'      : 'Precision-Recall Curve',
    'F1_curve.png'      : 'F1 Confidence Curve',
}

for filename, title in plot_files.items():
    path = os.path.join(result_dir, filename)
    if os.path.exists(path):
        print(f"\n📊 {title}")
        img = mpimg.imread(path)
        plt.figure(figsize=(14, 8))
        plt.imshow(img)
        plt.axis('off')
        plt.title(title, fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.show()
    else:
        print(f"   (File {filename} tidak ditemukan, mungkin belum digenerate)")
# Out:
#    (File results.png tidak ditemukan, mungkin belum digenerate)
#    (File confusion_matrix.png tidak ditemukan, mungkin belum digenerate)
#    (File val_batch0_pred.jpg tidak ditemukan, mungkin belum digenerate)
#    (File PR_curve.png tidak ditemukan, mungkin belum digenerate)
#    (File F1_curve.png tidak ditemukan, mungkin belum digenerate)

# %% [markdown]
# ---
# ## Sel 8: 💾 Simpan Model ke Google Drive & Download
# > **Sangat penting!** Session Google Colab gratis bisa berakhir kapan saja. Jalankan sel ini segera setelah training selesai untuk menyimpan `best.pt` ke Google Drive supaya tidak hilang!

# %%
import shutil
from google.colab import files
import os

best_pt_path = f'runs/detect/runs/detect/{RUN_NAME}/weights/best.pt'
last_pt_path = f'runs/detect/runs/detect/{RUN_NAME}/weights/last.pt'

# ============================================================
# 1. SIMPAN KE GOOGLE DRIVE (backup aman)
# ============================================================
# Ganti path tujuan di Google Drive sesuai keinginan
GDRIVE_SAVE_DIR = '/content/drive/MyDrive/model_hasil_training'   # <-- GANTI JIKA PERLU

os.makedirs(GDRIVE_SAVE_DIR, exist_ok=True)

if os.path.exists(best_pt_path):
    dst = os.path.join(GDRIVE_SAVE_DIR, 'best.pt')
    shutil.copy2(best_pt_path, dst)
    size_mb = os.path.getsize(dst) / 1024 / 1024
    print(f"✅ best.pt berhasil disimpan ke Google Drive!")
    print(f"   Path   : {dst}")
    print(f"   Ukuran : {size_mb:.2f} MB")
else:
    print(f"❌ best.pt tidak ditemukan di: {best_pt_path}")

if os.path.exists(last_pt_path):
    dst_last = os.path.join(GDRIVE_SAVE_DIR, 'last.pt')
    shutil.copy2(last_pt_path, dst_last)
    print(f"✅ last.pt berhasil disimpan ke Google Drive!")

# Simpan juga folder hasil training lengkap (grafik, dll)
results_zip_dst = os.path.join(GDRIVE_SAVE_DIR, f'{RUN_NAME}_results.zip')
shutil.make_archive(
    base_name = results_zip_dst.replace('.zip', ''),
    format    = 'zip',
    root_dir  = f'runs/detect/runs/detect/{RUN_NAME}'
)
print(f"✅ Hasil training lengkap (grafik, dll) tersimpan ke Google Drive!")
print(f"   Path: {results_zip_dst}")

print("\n" + "="*60)
print("  Semua file sudah aman di Google Drive!")
print("  Sekarang jalankan sel berikutnya untuk download ke laptop.")
print("="*60)
# Out:
# ✅ best.pt berhasil disimpan ke Google Drive!
#    Path   : /content/drive/MyDrive/model_hasil_training/best.pt
#    Ukuran : 5.96 MB
# ✅ last.pt berhasil disimpan ke Google Drive!
# ✅ Hasil training lengkap (grafik, dll) tersimpan ke Google Drive!
#    Path: /content/drive/MyDrive/model_hasil_training/model_gudang_v2_results.zip
#
# ============================================================
#   Semua file sudah aman di Google Drive!
#   Sekarang jalankan sel berikutnya untuk download ke laptop.
# ============================================================

# %% [markdown]
# ---
# ## Sel 9: ⬇️ Download best.pt ke Laptop

# %%
from google.colab import files

best_pt_path = f'runs/detect/runs/detect/{RUN_NAME}/weights/best.pt'

print(f"⬇️  Mendownload {best_pt_path} ke laptop...")
print("   (Dialog download akan muncul di browser Mas Luthfi)")
files.download(best_pt_path)
print("✅ Download selesai!")
print("\n📌 Langkah selanjutnya:")
print("   1. Pindahkan file best.pt yang baru ke folder project laptop Mas Luthfi")
print("   2. Ganti file best.pt yang lama dengan yang baru")
print("   3. Jalankan python app.py untuk menguji model baru!")
# Out:
# ⬇️  Mendownload runs/detect/runs/detect/model_gudang_v2/weights/best.pt ke laptop...
#    (Dialog download akan muncul di browser Mas Luthfi)
# ✅ Download selesai!
#
# 📌 Langkah selanjutnya:
#    1. Pindahkan file best.pt yang baru ke folder project laptop Mas Luthfi
#    2. Ganti file best.pt yang lama dengan yang baru
#    3. Jalankan python app.py untuk menguji model baru!

# %% [markdown]
# ---
# ## Sel 10 (OPSIONAL): 🔄 Lanjutkan Training dari Checkpoint
# > Jalankan sel ini **HANYA JIKA** training sebelumnya terhenti di tengah jalan (misal karena session Colab habis) dan Mas Luthfi ingin melanjutkan dari epoch terakhir tanpa mengulang dari awal.

# %%
# OPSIONAL: Lanjutkan training dari checkpoint last.pt
# Jalankan sel ini hanya jika training terhenti di tengah jalan

from ultralytics import YOLO

# Load dari Google Drive (jika session Colab baru)
last_pt_from_drive = os.path.join(GDRIVE_SAVE_DIR, 'last.pt')

if os.path.exists(last_pt_from_drive):
    print(f"✅ Menemukan checkpoint: {last_pt_from_drive}")
    model_resume = YOLO(last_pt_from_drive)
    results = model_resume.train(
        data    = YAML_PATH,
        resume  = True,       # <-- Kunci: lanjutkan dari epoch terakhir
        epochs  = 100,
        project = 'runs/detect',
        name    = RUN_NAME,
    )
    print("✅ Training lanjutan selesai!")
else:
    print(f"❌ File last.pt tidak ditemukan di Google Drive: {last_pt_from_drive}")
    print("   Pastikan Sel 8 sudah pernah dijalankan untuk menyimpan checkpoint ke Drive.")
# Out:
# ✅ Menemukan checkpoint: /content/drive/MyDrive/model_hasil_training/last.pt
# WARNING ⚠️ model '/content/drive/MyDrive/model_hasil_training/last.pt' is not a resumable training checkpoint (missing epoch/optimizer state). Use 'resume' only to continue incomplete training. Starting new training instead.
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset_final/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/model_hasil_training/last.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=model_gudang_v2-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/detect/model_gudang_v2-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    758722  ultralytics.nn.modules.head.Detect           [38, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,018,258 parameters, 3,018,242 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4960.8±999.5 MB/s, size: 1384.4 KB)
# train: Scanning /content/dataset_final/train/labels.cache... 710 images, 102 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 710/710 229.1Mit/s 0.0s
# train: /content/dataset_final/train/images/20260704_105439.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260704_105444.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260715_102226.jpg: corrupt JPEG restored and saved
# train: /content/dataset_final/train/images/20260715_102819.jpg: corrupt JPEG restored and saved
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 3188, len(boxes) = 3651. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 1769.3±1849.7 MB/s, size: 1117.1 KB)
# val: Scanning /content/dataset_final/val/labels.cache... 98 images, 16 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 98/98 4.4Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 606. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000238, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/runs/detect/runs/detect/model_gudang_v2-2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/model_gudang_v2-2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.14G     0.8644     0.6163      1.019         74        640: 100% ━━━━━━━━━━━━ 45/45 1.4s/it 1:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s
#                    all         98        606      0.767      0.824      0.852      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.31G     0.6641     0.5688     0.9565         34        640: 100% ━━━━━━━━━━━━ 45/45 1.3s/it 57.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s
#                    all         98        606      0.826      0.776      0.855      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.32G     0.6694     0.5634      0.941         57        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606       0.74      0.839       0.85      0.733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.32G     0.6491     0.5579     0.9482         79        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 56.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.753      0.853       0.85      0.743
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.32G     0.6446      0.562     0.9501        144        640: 100% ━━━━━━━━━━━━ 45/45 1.1s/it 50.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5it/s 1.6s
#                    all         98        606      0.754      0.857      0.851      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.32G     0.6211     0.5362     0.9311         69        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 52.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.4it/s 0.9s
#                    all         98        606      0.684      0.895      0.855      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.32G     0.6309     0.5427     0.9357         18        640: 100% ━━━━━━━━━━━━ 45/45 1.2s/it 54.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s
#                    all         98        606      0.755      0.846      0.856      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.32G     0.6247      0.535      0.942        165        640: 53% ━━━━━━────── 24/45 3.0it/s 28.4s<7.0s

# %% [markdown]
# ---
# ## 📖 Catatan Penting
#
# | # | Hal | Penjelasan |
# |---|-----|------------|
# | 1 | **Session Timeout** | Google Colab gratis akan otomatis disconnect setelah ~12 jam atau jika browser ditutup. Selalu simpan ke Drive dulu! |
# | 2 | **OOM (Out of Memory)** | Jika muncul error CUDA OOM, turunkan `batch` dari `16` ke `8` di Sel 5. |
# | 3 | **mAP rendah** | Coba tambah data augmentasi atau perbanyak gambar di class yang sedikit. |
# | 4 | **best.pt vs last.pt** | Selalu gunakan `best.pt` untuk deployment. `last.pt` hanya untuk resume training. |
# | 5 | **Format label campuran** | Dataset ini menggunakan Bounding Box (data lama) + Polygon (data baru dari Roboflow). YOLOv8 mendukung keduanya. |
#
# ---
# *Notebook ini dibuat untuk skripsi Computer Vision Mas Luthfi & Lisna* 🎓
